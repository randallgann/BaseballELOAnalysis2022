# %%
import pandas as pd
from datetime import date


# %load_ext nb_black

# %%
df = pd.read_csv("mlb-elo/mlb_elo.csv")

# %%
df.head()
# Out:
#          date  season  neutral playoff team1 team2     elo1_pre     elo2_pre  \
# 0  2022-10-04    2022        0     NaN   TEX   NYY  1457.030338  1524.500391
# 1  2022-10-04    2022        0     NaN   SEA   DET  1509.244426  1484.621492
# 2  2022-10-04    2022        0     NaN   SDP   SFG  1501.135403  1562.747346
# 3  2022-10-04    2022        0     NaN   PIT   STL  1460.306361  1529.976795
# 4  2022-10-04    2022        0     NaN   OAK   ANA  1523.767041  1488.328628
#
#    elo_prob1  elo_prob2  ...  pitcher1_rgs  pitcher2_rgs  pitcher1_adj  \
# 0   0.437766   0.562234  ...           NaN           NaN           NaN
# 1   0.569521   0.430479  ...           NaN           NaN           NaN
# 2   0.446083   0.553917  ...           NaN           NaN           NaN
# 3   0.434651   0.565349  ...           NaN           NaN           NaN
# 4   0.584714   0.415286  ...           NaN           NaN           NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225857 entries, 0 to 225856
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          225857 non-null  object
#  1   season        225857 non-null  int64
#  2   neutral       225857 non-null  int64
#  3   playoff       1707 non-null    object
#  4   team1         225857 non-null  object
#  5   team2         225857 non-null  object
#  6   elo1_pre      225857 non-null  float64
#  7   elo2_pre      225857 non-null  float64
#  8   elo_prob1     225857 non-null  float64
#  9   elo_prob2     225857 non-null  float64
#  10  elo1_post     223563 non-null  float64
#  11  elo2_post     223563 non-null  float64
#  12  rating1_pre   225857 non-null  float64
#  13  rating2_pre   225857 non-null  float64
#  14  pitcher1      223656 non-null  object
#  15  pitcher2      223654 non-null  object
#  16  pitcher1_rgs  189953 non-null  float64
# ...

# %%
df.shape
# Out:
# (225857, 26)

# %%
gamesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225857 entries, 0 to 225856
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          225857 non-null  datetime64[ns]
#  1   season        225857 non-null  int64
#  2   neutral       225857 non-null  int64
#  3   playoff       1707 non-null    object
#  4   team1         225857 non-null  object
#  5   team2         225857 non-null  object
#  6   elo1_pre      225857 non-null  float64
#  7   elo2_pre      225857 non-null  float64
#  8   elo_prob1     225857 non-null  float64
#  9   elo_prob2     225857 non-null  float64
#  10  elo1_post     223563 non-null  float64
#  11  elo2_post     223563 non-null  float64
#  12  rating1_pre   225857 non-null  float64
#  13  rating2_pre   225857 non-null  float64
#  14  pitcher1      223656 non-null  object
#  15  pitcher2      223654 non-null  object
#  16  pitcher1_rgs  189953 non-null  float64
# ...

# %%
gamesData.head()
#gamesData.sample(n=10, random_state=1)
# Out:
#         date  season  neutral playoff team1 team2     elo1_pre     elo2_pre  \
# 0 2022-10-04    2022        0     NaN   TEX   NYY  1457.030338  1524.500391
# 1 2022-10-04    2022        0     NaN   SEA   DET  1509.244426  1484.621492
# 2 2022-10-04    2022        0     NaN   SDP   SFG  1501.135403  1562.747346
# 3 2022-10-04    2022        0     NaN   PIT   STL  1460.306361  1529.976795
# 4 2022-10-04    2022        0     NaN   OAK   ANA  1523.767041  1488.328628
#
#    elo_prob1  elo_prob2  ...  pitcher1_rgs  pitcher2_rgs  pitcher1_adj  \
# 0   0.437766   0.562234  ...           NaN           NaN           NaN
# 1   0.569521   0.430479  ...           NaN           NaN           NaN
# 2   0.446083   0.553917  ...           NaN           NaN           NaN
# 3   0.434651   0.565349  ...           NaN           NaN           NaN
# 4   0.584714   0.415286  ...           NaN           NaN           NaN
#
#    pitcher2_adj rating_prob1 rating_prob2  rating1_post  rating2_post  score1  \
# ...

# %%
# creating a copy of the data
gamesData = df.copy()

# %%
# convert date column to datetime format
gamesData['date'] = pd.to_datetime(gamesData['date'])

# %%
# we have games that haven't been played yet - removing those
today = date.today().strftime("%Y-%m-%d")
gamesData = gamesData[gamesData['date']<str(today)]

# %%
gamesData.shape
# Out:
# (223555, 26)

# %%
gamesData.head()
# Out:
#            date  season  neutral playoff team1 team2     elo1_pre  \
# 2302 2022-04-16    2022        0     NaN   LAD   CIN  1578.161909
# 2303 2022-04-16    2022        0     NaN   SEA   HOU  1511.804364
# 2304 2022-04-16    2022        0     NaN   COL   CHC  1499.930827
# 2305 2022-04-16    2022        0     NaN   MIL   STL  1517.306389
# 2306 2022-04-16    2022        0     NaN   TEX   ANA  1459.861604
#
#          elo2_pre  elo_prob1  elo_prob2  ...  pitcher1_rgs  pitcher2_rgs  \
# 2302  1496.253972   0.647862   0.352138  ...     54.482800     47.501874
# 2303  1544.066397   0.488112   0.511888  ...     49.872809     61.505673
# 2304  1476.952474   0.567198   0.432802  ...     53.089074     44.931370
# 2305  1528.476951   0.518455   0.481545  ...     52.020523     49.334096
# 2306  1485.497361   0.497646   0.502354  ...     47.959732     52.258450
#
#       pitcher1_adj  pitcher2_adj rating_prob1 rating_prob2  rating1_post  \
# ...

# %%
gamesData["fav_538_won"] = gamesData.apply(
    lambda x: 1
    if x["rating_prob1"] > x["rating_prob2"]
    and x["score1"] > x["score2"]
    or x["rating_prob1"] < x["rating_prob2"]
    and x["score1"] < x["score2"]
    else 0,
    axis=1,
)

# %%
gamesData["fav_538_prob"] = gamesData.apply(
    lambda x: x["rating_prob1"]
    if x["rating_prob1"] > x["rating_prob2"]
    else x["rating_prob2"],
    axis=1,
)

# %%
# checking a random sample of 20 after adding fav_538_won column
gamesData.sample(n=20, random_state=1)
# Out:
#              date  season  neutral playoff team1 team2     elo1_pre  \
# 39074  2006-07-06    2006        0     NaN   ATL   CIN  1497.972000
# 109352 1974-05-06    1974        0     NaN   ANA   CLE  1507.963000
# 14350  2016-07-16    2016        0     NaN   ARI   LAD  1469.099732
# 43722  2004-07-31    2004        0     NaN   CIN   HOU  1465.173000
# 13543  2016-09-13    2016        0     NaN   ANA   SEA  1497.159222
# 115757 1970-09-04    1970        0     NaN   TEX   DET  1499.384000
# 112632 1972-07-06    1972        0     NaN   HOU   PIT  1526.674000
# 112548 1972-07-12    1972        0     NaN   WSN   SDP  1465.927000
# 137785 1956-07-12    1956        0     NaN   CHC   PIT  1480.539000
# 23916  2012-08-08    2012        0     NaN   LAD   COL  1509.153000
# 184926 1918-05-28    1918        0     NaN   BOS   CHW  1534.408000
# 73817  1991-07-04    1991        0     NaN   BOS   DET  1515.410000
# 180161 1922-06-10    1922        0     NaN   PHI   STL  1434.206000
# ...
